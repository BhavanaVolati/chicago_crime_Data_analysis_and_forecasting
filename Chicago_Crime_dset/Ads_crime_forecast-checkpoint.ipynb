# %%
# !pip install pystan~=2.14
# !pip install prophet
# Out:
# Requirement already satisfied: pystan~=2.14 in c:\users\ravi\anaconda3\lib\site-packages (2.19.1.1)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in c:\users\ravi\anaconda3\lib\site-packages (from pystan~=2.14) (0.29.32)
# Requirement already satisfied: numpy>=1.7 in c:\users\ravi\anaconda3\lib\site-packages (from pystan~=2.14) (1.21.5)
# Collecting prophet
#   Obtaining dependency information for prophet from https://files.pythonhosted.org/packages/24/2b/834e9a347f2f0161e32a3c6125b8a1ebdf6ac33199a0ed3a0bdf1f0c296f/prophet-1.1.5-py3-none-win_amd64.whl.metadata
#   Downloading prophet-1.1.5-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Obtaining dependency information for cmdstanpy>=1.0.4 from https://files.pythonhosted.org/packages/5b/a0/a0f4a556dff2189bc08d0f69f0d4aac1b7e4e0cedc9a70b30a134f73d100/cmdstanpy-1.2.1-py3-none-any.whl.metadata
#   Downloading cmdstanpy-1.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\ravi\anaconda3\lib\site-packages (from prophet) (1.21.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\ravi\anaconda3\lib\site-packages (from prophet) (3.8.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\ravi\anaconda3\lib\site-packages (from prophet) (1.4.4)
# Collecting holidays>=0.25 (from prophet)
#   Obtaining dependency information for holidays>=0.25 from https://files.pythonhosted.org/packages/91/7a/2c5c043e4a7cff3dbab6b0f3a79b492e76c7dc1a06f309897509c9d467f5/holidays-0.44-py3-none-any.whl.metadata
#   Using cached holidays-0.44-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\ravi\anaconda3\lib\site-packages (from prophet) (4.64.1)
# Requirement already satisfied: importlib-resources in c:\users\ravi\anaconda3\lib\site-packages (from prophet) (6.1.1)
# Collecting stanio~=0.3.0 (from cmdstanpy>=1.0.4->prophet)
#   Obtaining dependency information for stanio~=0.3.0 from https://files.pythonhosted.org/packages/26/01/e2579afa3ad1eade8b54bf5b9e45790d219681b1f8f97edbd2f18c4e1a7d/stanio-0.3.0-py3-none-any.whl.metadata
#   Downloading stanio-0.3.0-py3-none-any.whl.metadata (963 bytes)
# Requirement already satisfied: python-dateutil in c:\users\ravi\anaconda3\lib\site-packages (from holidays>=0.25->prophet) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (21.3)
# Requirement already satisfied: pillow>=8 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ravi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (2.4.7)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ravi\anaconda3\lib\site-packages (from importlib-resources->prophet) (3.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ravi\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2022.1)
# Requirement already satisfied: colorama in c:\users\ravi\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.5)
# Requirement already satisfied: six in c:\users\ravi\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=2.0.0->prophet) (1.16.0)
# Downloading prophet-1.1.5-py3-none-win_amd64.whl (13.3 MB)
#    ---------------------------------------- 13.3/13.3 MB 5.5 MB/s eta 0:00:00
# Downloading cmdstanpy-1.2.1-py3-none-any.whl (93 kB)
#    ---------------------------------------- 93.7/93.7 kB 5.2 MB/s eta 0:00:00
# Using cached holidays-0.44-py3-none-any.whl (922 kB)
# Downloading stanio-0.3.0-py3-none-any.whl (6.2 kB)
# Installing collected packages: stanio, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.1 holidays-0.44 prophet-1.1.5 stanio-0.3.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet

# %%
data1 = pd.read_csv(r"C:/Users/Ravi/Desktop/archive (2)/Chicago_Crimes_2005_to_2007.csv",low_memory=False)

# %%
data2 = pd.read_csv(r"C:/Users/Ravi/Desktop/archive (2)/Chicago_Crimes_2008_to_2011.csv",low_memory=False)

# %%
data3 = pd.read_csv(r"C:/Users/Ravi/Desktop/archive (2)/Chicago_Crimes_2012_to_2017.csv",low_memory=False)

# %%
data = pd.concat([data1,data2,data3])

# %% [markdown]
# **Brief overview about colums**:
#
# ID: Unique identifier for the crime incident.
# Case Number: Records Division Number assigned to the incident.
# Date: Date when the incident occurred.
# Block: Block address of the incident.
# IUCR: The Illinois Uniform Crime Reporting code.
# Primary Type: The primary description of the crime according to the IUCR code.
# Description: Secondary description of the incident.
# Location Description: Description of the location where the incident occurred.
# Arrest: True or False if the suspect was arrested.
# Domestic: True or False if the incident was domestic-related.
# Beat: A beat is the smallest police geographic area; each beat has a dedicated police beat car.
# District: District where the incident occurred.
# Ward: The City Council district where the incident occurred.
# Community Area: Chicago has 77 community areas.
# FBI Code: Crime classification according to the FBI’s National Incident-Based Reporting System (NIBRS).
# X Coordinate: The x-coordinate of the incident.
# Y Coordinate: The y-coordinate of the incident.
# Year: Year the incident occurred.
# Updated On: Date and time the record was last updated.
# Latitude: The latitude of the incident.
# Longitude: The longitude of the incident.
# Location: The location of the incident.

# %% [markdown]
# **1. Display Top 5 Rows of The Dataset**

# %%
data.head()
# Out:
#    Unnamed: 0       ID Case Number             Date                Block  \
# 0           0  4673626    HM274058   2006-4-2 13:00    055XX N MANGO AVE
# 1           1  4673627    HM202199  2006-2-26 13:40   065XX S RHODES AVE
# 2           2  4673628    HM113861   2006-1-8 23:16      013XX E 69TH ST
# 3           4  4673629    HM274049   2006-4-5 18:45  061XX W NEWPORT AVE
# 4           5  4673630    HM187120  2006-2-17 21:03      037XX W 60TH ST
#
#    IUCR   Primary Type                   Description Location Description  \
# 0  2825  OTHER OFFENSE       HARASSMENT BY TELEPHONE            RESIDENCE
# 1  2017      NARCOTICS            MANU/DELIVER:CRACK             SIDEWALK
# 2  051A        ASSAULT           AGGRAVATED: HANDGUN                OTHER
# 3   460        BATTERY                        SIMPLE            RESIDENCE
# 4  1811      NARCOTICS  POSS: CANNABIS 30GMS OR LESS                ALLEY
#
#    Arrest  ...  Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# 0   False  ...            11.0        26     1136872.0     1936499.0  2006
# 1    True  ...            42.0        18     1181027.0     1861693.0  2006
# 2   False  ...            69.0       04A     1186023.0     1859609.0  2006
# 3   False  ...            17.0       08B     1134772.0     1922299.0  2006
# 4    True  ...            65.0        18     1152412.0     1864560.0  2006
#
#        Updated On   Latitude  Longitude                       Location  \
# 0  2016-4-15 8:55  41.981913 -87.771996  (41.981912692, -87.771996382)
# 1  2016-4-15 8:55  41.775733 -87.611920  (41.775732538, -87.611919814)
# 2  2016-4-15 8:55  41.769897 -87.593671  (41.769897392, -87.593670899)
# 3  2016-4-15 8:55  41.942984 -87.780057  (41.942984005, -87.780056951)
# 4  2016-4-15 8:55  41.784211 -87.716745   (41.784210853, -87.71674491)
#
#   Unnamed: 23
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **2. Check Last 5 Rows of The Dataset**

# %%
data.tail()
# Out:
#          Unnamed: 0        ID Case Number                    Date  \
# 1456709     6250330  10508679    HZ250507  05/03/2016 11:33:00 PM
# 1456710     6251089  10508680    HZ250491  05/03/2016 11:30:00 PM
# 1456711     6251349  10508681    HZ250479  05/03/2016 12:15:00 AM
# 1456712     6253257  10508690    HZ250370  05/03/2016 09:07:00 PM
# 1456713     6253474  10508692    HZ250517  05/03/2016 11:38:00 PM
#
#                         Block  IUCR     Primary Type              Description  \
# 1456709       026XX W 23RD PL  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456710   073XX S HARVARD AVE  1310  CRIMINAL DAMAGE              TO PROPERTY
# 1456711       024XX W 63RD ST  041A          BATTERY      AGGRAVATED: HANDGUN
# 1456712  082XX S EXCHANGE AVE  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456713       001XX E 75TH ST  5007    OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  ...  Community Area  \
# 1456709                       APARTMENT    True  ...            30.0
# 1456710                       APARTMENT    True  ...            69.0
# 1456711                        SIDEWALK   False  ...            66.0
# 1456712                        SIDEWALK   False  ...            46.0
# 1456713  PARKING LOT/GARAGE(NON.RESID.)    True  ...            69.0
#
#          FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 1456709       08B     1159105.0     1888300.0  2016  05/10/2016 03:56:50 PM
# 1456710        14     1175230.0     1856183.0  2016  05/10/2016 03:56:50 PM
# 1456711       04B     1161027.0     1862810.0  2016  05/10/2016 03:56:50 PM
# 1456712       08B     1197261.0     1850727.0  2016  05/10/2016 03:56:50 PM
# 1456713        26     1178696.0     1855324.0  2016  05/10/2016 03:56:50 PM
#
#           Latitude  Longitude                       Location Unnamed: 23
# 1456709  41.849222 -87.691556   (41.849222028, -87.69155551)         NaN
# 1456710  41.760744 -87.633335   (41.760743949, -87.63333531)         NaN
# 1456711  41.779235 -87.685207  (41.779234743, -87.685207125)         NaN
# 1456712  41.745252 -87.552773  (41.745251975, -87.552773464)         NaN
# 1456713  41.758309 -87.620658   (41.75830866, -87.620658418)         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# **3. Shape(Number of Rows And Number of Columns)**

# %%
data.shape
# Out:
# (3553864, 24)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 3553864
# Number of Columns 24

# %% [markdown]
# **4.Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3553864 entries, 0 to 1456713
# Data columns (total 24 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   ID                    int64
#  2   Case Number           object
#  3   Date                  object
#  4   Block                 object
#  5   IUCR                  object
#  6   Primary Type          object
#  7   Description           object
#  8   Location Description  object
#  9   Arrest                bool
#  10  Domestic              bool
#  11  Beat                  int64
#  12  District              float64
#  13  Ward                  float64
#  14  Community Area        float64
#  15  FBI Code              object
#  16  X Coordinate          float64
#  17  Y Coordinate          float64
#  18  Year                  int64
#  19  Updated On            object
#  20  Latitude              float64
#  21  Longitude             float64
#  22  Location              object
#  23  Unnamed: 23           object
# dtypes: bool(2), float64(7), int64(4), object(11)
# memory usage: 630.4+ MB

# %% [markdown]
# **5.Null Values In The Dataset**

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# ID                            0
# Case Number                   4
# Date                          0
# Block                         0
# IUCR                          0
# Primary Type                  0
# Description                   0
# Location Description       1687
# Arrest                        0
# Domestic                      0
# Beat                          0
# District                     44
# Ward                         43
# Community Area              787
# FBI Code                      0
# X Coordinate              54670
# Y Coordinate              54670
# Year                          0
# Updated On                    0
# Latitude                  54670
# Longitude                 54670
# Location                  54670
# Unnamed: 23             3553863
# dtype: int64

# %% [markdown]
# **6. Select Only The Necessary Columns**

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Case Number', 'Date', 'Block', 'IUCR',
#        'Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code',
#        'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude',
#        'Longitude', 'Location', 'Unnamed: 23'],
#       dtype='object')

# %%
df = data[['ID','Date','Primary Type','Location Description','Arrest','Domestic']]

# %%
df.head()
# Out:
#         ID             Date   Primary Type Location Description  Arrest  \
# 0  4673626   2006-4-2 13:00  OTHER OFFENSE            RESIDENCE   False
# 1  4673627  2006-2-26 13:40      NARCOTICS             SIDEWALK    True
# 2  4673628   2006-1-8 23:16        ASSAULT                OTHER   False
# 3  4673629   2006-4-5 18:45        BATTERY            RESIDENCE   False
# 4  4673630  2006-2-17 21:03      NARCOTICS                ALLEY    True
#
#    Domestic
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %% [markdown]
# **7.Null Values In The Dataset**

# %%
df.isnull().sum()
# Out:
# ID                         0
# Date                       0
# Primary Type               0
# Location Description    1687
# Arrest                     0
# Domestic                   0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# ID                      0
# Date                    0
# Primary Type            0
# Location Description    0
# Arrest                  0
# Domestic                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3552177 entries, 0 to 1456713
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  object
#  2   Primary Type          object
#  3   Location Description  object
#  4   Arrest                bool
#  5   Domestic              bool
# dtypes: bool(2), int64(1), object(3)
# memory usage: 142.3+ MB

# %%
df.Date = pd.to_datetime(df.Date,format = '%Y/%m/%d %I:%M:%S %p')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509         try:
# --> 510             values, tz = conversion.datetime_to_datetime64(arg)
#     511             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26320\3427415461.py in <module>
# ----> 1 df.Date = pd.to_datetime(df.Date,format = '%Y/%m/%d %I:%M:%S %p')
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049             result = arg.map(cache_array)
#    1050         else:
# -> 1051             values = convert_listlike(arg._values, format)
#    1052             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     392
#     393     if format is not None:
# --> 394         res = _to_datetime_with_format(
#     395             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396         )
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512             return DatetimeIndex._simple_new(dta, name=name)
#     513         except (ValueError, TypeError):
# --> 514             raise err
#     515
#     516
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     499
#     500         # fallback
# --> 501         res = _array_strptime_with_fallback(
#     502             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503         )
#
# ~\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     435
#     436     try:
# --> 437         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438         if "%Z" in fmt or "%z" in fmt:
#     439             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2006-4-2 13:00' does not match format '%Y/%m/%d %I:%M:%S %p' (match)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3552177 entries, 2006-04-02 13:00:00 to 2016-05-03 23:38:00
# Data columns (total 6 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  object
#  2   Primary Type          object
#  3   Location Description  object
#  4   Arrest                bool
#  5   Domestic              bool
# dtypes: bool(2), int64(1), object(3)
# memory usage: 142.3+ MB

# %% [markdown]
# **8.Top 10 Primary Crime Types**

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Primary Type', 'Location Description', 'Arrest',
#        'Domestic'],
#       dtype='object')

# %%
df['Primary Type'].value_counts().head(10)
# Out:
# THEFT                  741717
# BATTERY                641300
# CRIMINAL DAMAGE        411188
# NARCOTICS              395458
# OTHER OFFENSE          217670
# ASSAULT                215060
# BURGLARY               208199
# MOTOR VEHICLE THEFT    153775
# DECEPTIVE PRACTICE     141728
# ROBBERY                134657
# Name: Primary Type, dtype: int64

# %% [markdown]
# **9 .How Many Criminals Are Arrested Having Primary Crime type is Theft?**

# %%
df[df['Primary Type']=="THEFT"]['Arrest'].value_counts()
# Out:
# False    657715
# True      84002
# Name: Arrest, dtype: int64

# %% [markdown]
# **10. Find The Top 10 Crime Location Descriptions**

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'Primary Type', 'Location Description', 'Arrest',
#        'Domestic'],
#       dtype='object')

# %%
df['Location Description'].value_counts().head(10)
# Out:
# STREET                            881937
# RESIDENCE                         579464
# APARTMENT                         402059
# SIDEWALK                          400380
# OTHER                             128906
# PARKING LOT/GARAGE(NON.RESID.)     97426
# ALLEY                              81023
# SCHOOL, PUBLIC, BUILDING           74533
# RESIDENCE-GARAGE                   69322
# VEHICLE NON-COMMERCIAL             64197
# Name: Location Description, dtype: int64

# %% [markdown]
# **11 .How Many of Are Arrested Having Location Type is STREET**

# %%
df[df['Location Description']=="STREET"]['Arrest'].value_counts()
# Out:
# False    633841
# True     248096
# Name: Arrest, dtype: int64

# %%
df.index = pd.DatetimeIndex(df.Date)

# %%
df
# Out:
#                            ID                    Date     Primary Type  \
# Date
# 2006-04-02 13:00:00   4673626          2006-4-2 13:00    OTHER OFFENSE
# 2006-02-26 13:40:00   4673627         2006-2-26 13:40        NARCOTICS
# 2006-01-08 23:16:00   4673628          2006-1-8 23:16          ASSAULT
# 2006-04-05 18:45:00   4673629          2006-4-5 18:45          BATTERY
# 2006-02-17 21:03:00   4673630         2006-2-17 21:03        NARCOTICS
# ...                       ...                     ...              ...
# 2016-05-03 23:33:00  10508679  05/03/2016 11:33:00 PM          BATTERY
# 2016-05-03 23:30:00  10508680  05/03/2016 11:30:00 PM  CRIMINAL DAMAGE
# 2016-05-03 00:15:00  10508681  05/03/2016 12:15:00 AM          BATTERY
# 2016-05-03 21:07:00  10508690  05/03/2016 09:07:00 PM          BATTERY
# 2016-05-03 23:38:00  10508692  05/03/2016 11:38:00 PM    OTHER OFFENSE
#
#                                Location Description  Arrest  Domestic
# Date
# 2006-04-02 13:00:00                       RESIDENCE   False     False
# 2006-02-26 13:40:00                        SIDEWALK    True     False
# 2006-01-08 23:16:00                           OTHER   False     False
# 2006-04-05 18:45:00                       RESIDENCE   False     False
# 2006-02-17 21:03:00                           ALLEY    True     False
# ...                                             ...     ...       ...
# 2016-05-03 23:33:00                       APARTMENT    True      True
# 2016-05-03 23:30:00                       APARTMENT    True      True
# 2016-05-03 00:15:00                        SIDEWALK   False     False
# 2016-05-03 21:07:00                        SIDEWALK   False      True
# 2016-05-03 23:38:00  PARKING LOT/GARAGE(NON.RESID.)    True     False
#
# [3552177 rows x 6 columns]

# %%
plt.plot(df.resample('Y').size())
plt.title("Crime Count Per Year")
plt.xlabel("Years")
plt.ylabel("Number of Crimes")
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %%
plt.plot(df.resample('M').size())
plt.title("Crime Count Per Year")
plt.xlabel("Years")
plt.ylabel("Number of Crimes")
# Out:
# Text(0, 0.5, 'Number of Crimes')

# %% [markdown]
# **Preparing The data**

# %%
df_prophet = pd.DataFrame(df.resample('M').size().reset_index())

# %%
df_prophet.columns =['Date','Crime Count']

# %%
df_prophet
# Out:
#           Date  Crime Count
# 0   2005-01-31          282
# 1   2005-02-28          114
# 2   2005-03-31          135
# 3   2005-04-30          186
# 4   2005-05-31          214
# ..         ...          ...
# 140 2016-09-30        23176
# 141 2016-10-31        23243
# 142 2016-11-30        21077
# 143 2016-12-31        19517
# 144 2017-01-31        11329
#
# [145 rows x 2 columns]

# %% [markdown]
# **Rename The Columns**

# %%
df_prophet=df_prophet.rename(columns={'Date':'ds','Crime Count':'y'})

# %%
df_prophet
# Out:
#             ds      y
# 0   2005-01-31    282
# 1   2005-02-28    114
# 2   2005-03-31    135
# 3   2005-04-30    186
# 4   2005-05-31    214
# ..         ...    ...
# 140 2016-09-30  23176
# 141 2016-10-31  23243
# 142 2016-11-30  21077
# 143 2016-12-31  19517
# 144 2017-01-31  11329
#
# [145 rows x 2 columns]

# %% [markdown]
# **Train The Model**

# %%
m = Prophet()
m.fit(df_prophet)
# Out:
# 14:54:10 - cmdstanpy - INFO - Chain [1] start processing
# 14:54:11 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# **Make The Predictions**

# %%
pred=m.make_future_dataframe(periods=24,freq='M')
forcast = m.predict(pred)

# %%
forcast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2005-01-31  27934.308622  -1607.170426  50540.129654  27934.308622
# 1   2005-02-28  27897.763968  -2026.591851  45279.152286  27897.763968
# 2   2005-03-31  27857.303814   4143.167328  51728.267120  27857.303814
# 3   2005-04-30  27818.148827   8839.981613  57411.759171  27818.148827
# 4   2005-05-31  27777.688674  10789.050071  59249.919332  27777.688674
# ..         ...           ...           ...           ...           ...
# 164 2018-09-30  19950.713174  -5368.063951  42715.278523  19935.836487
# 165 2018-10-31  19899.579263  -5141.285348  42138.509651  19883.420984
# 166 2018-11-30  19850.094833  -9060.708127  38669.785627  19832.476902
# 167 2018-12-31  19798.960921  -9805.543396  39486.028654  19779.966015
# 168 2019-01-31  19747.827010  -7830.225972  40941.954399  19727.142063
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    27934.308622    -2832.487846          -2832.487846          -2832.487846
# 1    27897.763968    -4845.426520          -4845.426520          -4845.426520
# 2    27857.303814      480.297821            480.297821            480.297821
# 3    27818.148827     4540.185182           4540.185182           4540.185182
# 4    27777.688674     7749.301040           7749.301040           7749.301040
# ..            ...             ...                   ...                   ...
# 164  19966.218849    -1917.800769          -1917.800769          -1917.800769
# 165  19916.334722    -1759.518912          -1759.518912          -1759.518912
# 166  19868.728350    -3664.045586          -3664.045586          -3664.045586
# 167  19819.212930    -4909.366923          -4909.366923          -4909.366923
# 168  19769.221103    -2650.867088          -2650.867088          -2650.867088
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -2832.487846  -2832.487846  -2832.487846                   0.0
# 1   -4845.426520  -4845.426520  -4845.426520                   0.0
# 2     480.297821    480.297821    480.297821                   0.0
# 3    4540.185182   4540.185182   4540.185182                   0.0
# 4    7749.301040   7749.301040   7749.301040                   0.0
# ..           ...           ...           ...                   ...
# 164 -1917.800769  -1917.800769  -1917.800769                   0.0
# 165 -1759.518912  -1759.518912  -1759.518912                   0.0
# 166 -3664.045586  -3664.045586  -3664.045586                   0.0
# 167 -4909.366923  -4909.366923  -4909.366923                   0.0
# 168 -2650.867088  -2650.867088  -2650.867088                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0  25101.820776
# 1                           0.0                         0.0  23052.337448
# 2                           0.0                         0.0  28337.601635
# 3                           0.0                         0.0  32358.334010
# 4                           0.0                         0.0  35526.989715
# ..                          ...                         ...           ...
# 164                         0.0                         0.0  18032.912406
# 165                         0.0                         0.0  18140.060351
# 166                         0.0                         0.0  16186.049246
# 167                         0.0                         0.0  14889.593999
# 168                         0.0                         0.0  17096.959922
#
# [169 rows x 16 columns]

# %%
m.plot(forcast,xlabel="Date",ylabel="Crime Rate")

# %% [markdown]
# **Save The Model**

# %%
import json
from prophet.serialize import model_to_json, model_from_json

with open('prophet_model.json', 'w') as fout:
    json.dump(model_to_json(m), fout)  # Save model

# %%
with open('prophet_model.json', 'r') as fin:
    m1 = model_from_json(json.load(fin))  # Load model
# Out:
# C:\Users\Ravi\anaconda3\lib\site-packages\prophet\serialize.py:172: FutureWarning: The behavior of Timestamp.utcfromtimestamp is deprecated, in a future version will return a timezone-aware Timestamp with UTC timezone. To keep the old behavior, use Timestamp.utcfromtimestamp(ts).tz_localize(None). To get the future behavior, use Timestamp.fromtimestamp(ts, 'UTC')
#   setattr(model, attribute, pd.Timestamp.utcfromtimestamp(model_dict[attribute]).tz_localize(None))

# %%
x = int(input("Enter Numbers Months to forecast"))
# Out:
# Enter Numbers Months to forecast24

# %%
pred = m1.make_future_dataframe(periods=x ,freq = "M")
forcast = m1.predict(pred)

# %%
forcast
# Out:
#             ds         trend    yhat_lower    yhat_upper   trend_lower  \
# 0   2005-01-31  27934.308622   1523.163033  48643.971795  27934.308622
# 1   2005-02-28  27897.763968   -302.250982  47307.853942  27897.763968
# 2   2005-03-31  27857.303814   5272.924471  51897.699076  27857.303814
# 3   2005-04-30  27818.148827   6942.325153  56700.830475  27818.148827
# 4   2005-05-31  27777.688674  11120.232270  59594.112583  27777.688674
# ..         ...           ...           ...           ...           ...
# 164 2018-09-30  19950.713174  -6965.641518  43327.097033  19935.036433
# 165 2018-10-31  19899.579263  -5346.417969  44280.630281  19883.030413
# 166 2018-11-30  19850.094833  -9459.758168  40878.732348  19832.340992
# 167 2018-12-31  19798.960921 -10355.071039  37616.094428  19780.143992
# 168 2019-01-31  19747.827010  -5855.192275  41096.022352  19727.413388
#
#       trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    27934.308622    -2832.487846          -2832.487846          -2832.487846
# 1    27897.763968    -4845.426520          -4845.426520          -4845.426520
# 2    27857.303814      480.297821            480.297821            480.297821
# 3    27818.148827     4540.185182           4540.185182           4540.185182
# 4    27777.688674     7749.301040           7749.301040           7749.301040
# ..            ...             ...                   ...                   ...
# 164  19966.080253    -1917.800769          -1917.800769          -1917.800769
# 165  19916.200282    -1759.518912          -1759.518912          -1759.518912
# 166  19868.336994    -3664.045586          -3664.045586          -3664.045586
# 167  19818.321735    -4909.366923          -4909.366923          -4909.366923
# 168  19768.461324    -2650.867088          -2650.867088          -2650.867088
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0   -2832.487846  -2832.487846  -2832.487846                   0.0
# 1   -4845.426520  -4845.426520  -4845.426520                   0.0
# 2     480.297821    480.297821    480.297821                   0.0
# 3    4540.185182   4540.185182   4540.185182                   0.0
# 4    7749.301040   7749.301040   7749.301040                   0.0
# ..           ...           ...           ...                   ...
# 164 -1917.800769  -1917.800769  -1917.800769                   0.0
# 165 -1759.518912  -1759.518912  -1759.518912                   0.0
# 166 -3664.045586  -3664.045586  -3664.045586                   0.0
# 167 -4909.366923  -4909.366923  -4909.366923                   0.0
# 168 -2650.867088  -2650.867088  -2650.867088                   0.0
#
#      multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                           0.0                         0.0  25101.820776
# 1                           0.0                         0.0  23052.337448
# 2                           0.0                         0.0  28337.601635
# 3                           0.0                         0.0  32358.334010
# 4                           0.0                         0.0  35526.989715
# ..                          ...                         ...           ...
# 164                         0.0                         0.0  18032.912406
# 165                         0.0                         0.0  18140.060351
# 166                         0.0                         0.0  16186.049246
# 167                         0.0                         0.0  14889.593999
# 168                         0.0                         0.0  17096.959922
#
# [169 rows x 16 columns]

# %%
figure = m1.plot(forcast, xlabel='Date', ylabel='Crime Rate')
